# %% [markdown]
# \section{Introduction}
# \subsection{Brain and behaviour}
# \subsubsection{Two opposing views have been advanced on the relationship between brain and behavior}
# Synthesis of five experimental traditions: anatomy, embryology, physiology, pharmacology, and psychology
#
# Ramón y Cajal: neuron doctrine, individual neurons are the elementary building blocks and signaling elements of the nervous system
#
# Modern electrophysiology: Johannes Müller, Emil du Bois-Reymond, Hermann von Helmholtz
#
# Franz Joseph Gall: theory of localization, led to phrenology
#
# Pierre Flourens: holistic view of the brain
#
# The central nervous system has seven main parts:
# \begin{enumerate}
#     \item Spinal cord: cervical, thoracic, lumbar, sacral regions
#     \item Medulla oblongata: digestion, breathing, control of heart rate
#     \item Pons: Cerebral hemispheres to the cerebellum
#     \item Cerebellum: movement, learning of motor skills
#     \item Midbrain: rostral to the pons, visual and auditory reflexes
#     \item Diencephalon: thalamus and hypothalamus
#     \item Cerebrum: basal ganglia, hippocampus, amygdaloid nuclei
#     \item Frontal lobe, Temporal lobe, Parietal lobe, Occipital lobe
# \end{enumerate}
#
# \subsubsection{The brain has distinct functional regions}
# Gyrus: crests of convolutions
#
# Sulcus: intervening grooves
#
# \subsubsection{The first strong evidence for localization of cognitive abilities came from studies of language disorders}
# Pierre Paul Broca: specific areas of the brain concerned with language
#
# Karl Wernicke, 1876: receptive aphasia as opposed to expressive malfunction
#
# Distributed processing
#
#
#
# Neurons
# 1. Intorduction
# neuron: nerve cells that transfer information within the body
# Brain, ganglia: groups of neurons, neurons bundled together -> nerves
# sensory/motor neurons, interneurons
#
# Epineurium, perineurium, endoneurium
#
# Neuron: is an electrically excitable cell that processes and transmits information through electrical and chemical signals. These signals between neurons occur via synapses, specialized connections with other cells. Neurons can connect to each other to form neural networks.
# Neuroni, hermosolu, neuron, nervcell
#
# Dendrites: are the branched projections of a neuron that act to propagate the electrochemical stimulation received from other neural cells to the cell body, or soma, of the neuron from which the dendrites project.
# Dendriitit, tuojahaarakkeet, dendriter,
# Soma, Cell body, Solukeskus, Cellkropp
# Neurofilaments
# Nissl body: Nisslin jyväset: karkean endoplasmakalvoston tihentymiä, proteiinisynteesi
#
# Axon: is a long, slender projection of a nerve cell, or neuron, that typically conducts electrical impulses away from the neuron's cell body.
#
# Unmyelinated axons, Ydintupettomat aksonit, omyeliniserade: Schwannin solut, yksinkertainen kerros
# Myelinated, Ydintupelliset, Myeliniserade: Schwannin soluista muodostunut monikerroksellinen ydintyppi eli myeliinituppi.
# keskushermosto: oligodendrogliasolut ääreishermosto: Schwannin solut
# Myelin: Myelin is a fatty white substance that surrounds the axon of some nerve cells, forming an electrically insulating layer. It is essential for the proper functioning of the nervous system. It is an outgrowth of a type of glial cell.
# Myelin sheath, Myeliiniytuppi, Myelinslida
#
# Nodes of Ranvier, Ranvierin kuroumia, Ranviers noder
#
# Synapse, Synapsi, Synapser
# Synapse cleft, Synapsirako, Synapsklyftan
#
# Neuroglia, Hermostotukikudos
# Glia: Glial cells, sometimes called neuroglia or simply glia are non-neuronal cells that maintain homeostasis, form myelin, and provide support and protection for neurons in the central nervous system and peripheral nervous system.
# Gliasolut, Gliaceller
#
# Ependymal cells, Ependyymisolu, Ependymala celler: Ependyma is the thin epithelium-like lining of the ventricular system of the brain and the central canal of the spinal cord. It is involved in the production of cerebrospinal fluid (CSF).
#
# Oligodendrocytes: Their main functions are to provide support and insulation to axons in the central nervous system of some vertebrates, equivalent to the function performed by Schwann cells in the peripheral nervous system.
# Astrosyytit: muodostavat verkoston, tukevat ja säätelevät (ionitapaino) hermosolujen toimintaa, arpikudoksessa
#
# Mikrogliasolut: fagosytoivia, tuottavat myös vasta-aineita
#
# Schwannin solut: ääreishermosto
#
# Satelliittisolut: ääreishermoston ganglioissa, ympäröivät hermosolujen solukeskuksia
#
# Nervous systems, Hermosto, Nervsystem
# 1. Introduction
# nervous systems consist of circuits of neurons and supprroting cells
# Information transfer and regulation
#
#
# 3. Neural plasticity
# loss ro addition of synapses, strengthening or weakening of signaling synapses
# Shortterm memory: temporary links in hippocampus
# Long-term memory: connections in cerebral cortex
# NMDA-reseptoririippuvainen malli: NMDA reagoi glutamaattiin, reagoi jos ärsyke on tarpeeksi suuri, jolloin ionikanavan läpi menee Ca2+-ioneja sytoplasmaan, jotka aktivoivat signaalireittejä.
#
# Skitsofrenia: välittäjäaineita epäsuhteessa
# Depressio: pienentynyt seratoniinin määrä
# Heroiini ja opium, dopamiinin määrä lisäntyy, dopamiinivälitteiset synapsit vähenevät
# Alzheimer:
# Parkinson:
#
#
# 2. Peripheral nervous system, Ääreishermosto, Perifera nervsystemet
# (transmit, sensory and motor signals)
# Ääreishermosto koostuu ganglioista ja hermosäiekimpuista
#
# 1. Somatic nervous system, Somaattinen hermosto, Somatiska nervsystemet
# Motor nerves: efferent neurons
# Sensory nerves: afferent neurons
#
# 2. Autonomic nervous system, Autonominen hermosto, Autonoma nervsystemet
# 1. Symphatetic, Sympaattinen, Sympatiska: active
# 2. Parasymphatetic, Parasympaattinen, Parasympatiska: passive, resting
# 3. Enteric: digestive organs
#
#
#
# II Central nervous system, Keskushermosto, Centrala nervsystemet CNS
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Spinal cord, Selkäydin, Ryggmärgen
# The spinal cord is a long, thin, tubular bundle of nervous tissue and support cells that extends from the medulla oblongata in the brainstem to the lumbar region of the vertebral column. The brain and spinal cord together make up the central nervous system (CNS).
# Brain, Aivot, Hjärnan
# The brain is an organ that serves as the center of the nervous system in all vertebrate and most invertebrate animals. Only a few invertebrates such as sponges, jellyfish, adult sea squirts and starfish do not have a brain; diffuse or localised nerve nets are present instead. The brain is located in the head, usually close to the primary sensory organs for such senses as vision, hearing, balance, taste, and smell.
# Medulla oblongata, ydinjatke, förlängda märgen: breathing hearth, digestion
# The medulla oblongata (or medulla) is located in the hindbrain, anterior to the cerebellum. The medulla oblongata is a cone-shaped neuronal mass responsible for multiple autonomic (involuntary) functions ranging from vomiting to sneezing. The medulla contains the cardiac, respiratory, vomiting and vasomotor centers and therefore deals with the autonomic functions of breathing, heart rate and blood pressure.
# Pons, Aivosilta, Hjärnbryggan:
# The pons is part of the brainstem, and in humans and other bipeds lies between the midbrain (above) and the medulla oblongata (below) and in front of the cerebellum.The functions of these four cranial nerves (V-VIII) include sensory roles in hearing, equilibrium, and taste, and in facial sensations such as touch and pain, as well as motor roles in eye movement, facial expressions, chewing, swallowing, and the secretion of saliva and tears.
# Mesencephalon or midbrain, Keskiaivot, Mitthjärnan: visual reflexes
# The midbrain or mesencephalon (from the Greek mesos, middle, and enkephalos, brain[1]) is a portion of the central nervous system associated with vision, hearing, motor control, sleep/wake, arousal (alertness), and temperature regulation.
# Diencephalon, Väliaivot, Mellanhjärnan: , thalamus and hypothalamus: sensory information, thermostat, törst
# The diencephalon is part of the prosencephalon (forebrain), which develops from the foremost primary cerebral vesicle. The prosencephalon differentiates into a caudal diencephalon and rostral telencephalon. The cerebral hemispheres develop from the sides of the telencephalon, each containing a lateral ventricle. The diencephalon consists of structures that are lateral to the third ventricle, and include the thalamus, the hypothalamus, the epithalamus and the subthalamus.
# Thalamus: välityskeskus aivokuorelle
# Hypothalamus: homeostaasi, vuorokausirytmi
#
# Cerebellum, Pikkuaivot, Lillhjärnan: movement, balance, motor skills, liike, tasapaino,
# The cerebellum (Latin for "little brain") is a region of the brain that plays an important role in motor control. It may also be involved in some cognitive functions such as attention and language, and in regulating fear and pleasure responses,[1] but its movement-related functions are the most solidly established. The cerebellum does not initiate movement, but it contributes to coordination, precision, and accurate timing. It receives input from sensory systems of the spinal cord and from other parts of the brain, and integrates these inputs to fine-tune motor activity.[2] Cerebellar damage produces disorders in fine movement, equilibrium, posture, and motor learning.
# Cerebrum, Isoaivot, Storhjärnan: right(left cerebral hemispheres
# Cortex, Aivokuori, Hjärnbarken:
# Broca : forming speech,
# Wernick: comprehension
# Frontal lobe, Otsalohko, Pannloben: motor cortex, planning, motorinen alue, tavoitteellisuus, aloitekyky
# Parietal lobe, Päälaenlohko, Hjässloben: somatosensory cortex, puhe, maku, lukeminen
# Temporal, Ohimolohko, Tinningloben : auditory, Kuuloalue
# Occipital, Takaraivolohko, Nackloben: visual, näkökeskus
#
# Reticular, retikulaarinen, retikulära: regulation of attention
# The reticular activating system (RAS), or extrathalamic control modulatory system, is a set of connected nuclei in the brains of vertebrates that is responsible for regulating wakefulness and sleep-wake transitions. As its name implies, its most influential component is the reticular formation.
# Limbic system, limbinen järjestelmä, limbic system: emotions, gustatory
# The limbic system (or paleomammalian brain) is a complex set of brain structures located on both sides of the thalamus, right under the cerebrum.[1] It is not a separate system but a collection of structures from the telencephalon, diencephalon, and mesencephalon.[2] It includes the olfactory bulbs, hippocampus, amygdala, anterior thalamic nuclei, fornix, columns of fornix, mammillary body, septum pellucidum, habenular commissure, cingulate gyrus, parahippocampal gyrus, limbic cortex, and limbic midbrain areas.The limbic system supports a variety of functions including epinephrine flow, emotion, behavior, motivation, long-term memory, and olfaction.[3] Emotional life is largely housed in the limbic system, and it has a great deal to do with the formation of memories.
# Amygdala, amygdala, amygdala: sexual
# he amygdalae (singular: amygdala; /əˈmɪɡdələ/; also corpus amygdaloideum; Latin, from Greek ἀμυγδαλή, amygdalē, 'almond', 'tonsil'[1]) are two almond-shaped groups of nuclei located deep and medially within the temporal lobes of the brain in complex vertebrates, including humans.[2] Shown in research to perform a primary role in the processing of memory, decision-making, and emotional reactions, the amygdalae are considered part of the limbic system.
# Hippocampus, Aivoturso, Hippocampus: memory, 3D-hahmottaminen, avaruudellinen kartta
#
# Corpus callosum, aivokurkiainen, hjärnbalken: right, left linkage
# Lateralisaatio vasen: looginen, oikea: tunteellinen
# The corpus callosum (/ˈkɔːrpəs kəˈloʊsəm/; Latin for "tough body"), also known as the callosal commissure, is a wide, flat bundle of neural fibers about 10 cm long beneath the cortex in the eutherian brain at the longitudinal fissure. It connects the left and right cerebral hemispheres and facilitates interhemispheric communication. It is the largest white matter structure in the brain, consisting of 200–250 million contralateral axonal projections.Contents
# Ventricle, Aivokammio, Ventriklar
#
#
# \section{Cell and Molecular Biology of the Neuron}
# \subsection{The cells of the nervous system}
#
# \subsection{Ion channels}
# Rapid and large changes in the electrical potential difference across the cell membrane
#
# \textbf{Ion channels, ionikanavat, jonkanaler}: integral membrane proteins, mediate changes in the membrane potential
#
# Neurological diseases: cystic fibrosis, skeletal muscle disease, cardiac arrhythmia
#
# \textbf{Ion transporters or pumps, ionipumppu, jonpumpar}:
#
# \subsubsection{Rapid signalling in the nervous system depends on ion channels}
# Ion channels:
# 1. Recognize and select specific ions
# 2. Open and close in response to specific electrical. mechanical, chemical signals
# 3.  Conduct ions across the membrane
#
# Neuronal signaling: regulated activation of different classes of ion channels, each of which is selective for specific ions.
#
# \textbf{Voltage-gated channels}
# \textbf{Ligand-gated channels}
# \textbf{Mechanically-gated channels}
#
#
#
#
# 3. Function
#
# 1. Resting potential, Lepopotentiaali eli lepokalvojännite, Vilopotential
# Electrochemical gradient: Na+/K+-pump creates an electrochemical gradient 3 Na out, 2 K in
# Selective ion channels: K diffuses until it reaches electrochemical equilibrium, Na cannot diffuse
# -> membrane potential, kalvojännite, membranpotential
#
# 2. Hyperpolarization and depolarization
# Na influx leads to decreased membrane potential
# 3. Action potential, Aktiopotentiaali eli aktiokalvojännite,  Aktionspotential
# Na influx triggers more Na channels, increased influx of Na, membrane potential is increased and tries to reach the Na electrochemical equilibrium
# Positive feedback
# Voltage-gated ion channels
#
# 4. Repolarization, Repolarisaatio, Repolarisation
# Na-channels are inactivated due to positive potential, K channels open both voltage-gated and normal, K diffuses towards electrochemical equilibrium
#
# 5. Refractory period, Refraktaariaika, Refraktionstid
# absolute refractory period, Na channels are inactive, relative refractory period, K voltage-gated channels close after a while
#
#
# \subsection{Electrical signals of nerve cells}
#
# \subsection{Voltage-dependent membrane permeability}
#
# \subsection{Ion channels and transporters}
#
# \subsection{Synaptic transmission}
# 4. Synapses, Synapsit, Synapser
# Neurotransmitters: Neurotransmitters are endogenous chemicals that enable neurotransmission. They transmit signals across a chemical synapse, such as in a neuromuscular junction, from one neuron (nerve cell) to another "target" neuron, muscle cell, or gland cell.
# Välittäjäaine: Hermoston välittäjäaineet eli neurotransmitterit ovat yhdisteitä, jotka välittävät, voimistavat, estävät tai mukauttavat hermosolun ja toisen solun välisiä sähköisiä signaaleja. Neurotransmittereiden ja neuromodulaattoreiden yhteinen nimitys on neuroregulaattori eli hermostoon vaikuttava aine.
# Neurotransmittor: En signalsubstans eller neurotransmittor är en molekyl som förmedlar en nervsignal på kemisk väg från en nervcell till en annan i nervsystemet. Neurotransmittorer existerar både i det centrala nervsystemet (CNS) och i det perifera nervsystemet (PNS). Neurotransmittorer lagras i vesiklar inom specialiserade ansvällningar på axonen som utgör den presynaptiska delen av synapsen, och som svar på en aktionspotential frisläpps de till den synaptiska klyftan.
#
# Function
# Action potential -> voltage-gated Ca channels are opened ->transmittervesicles are released -> receptors are activated
# Excitatory postsynaptic potential lEPSP: depolarisoi solukalvoa, Na tai Ca
# Inhibitory postsynaptic potential IPSP: hyperpolarisoi solukalvoa, K tai Cl
#
# Spatial and temporal summation
#
# \subsection{Neurotransmitters and their receptors}
#
# \subsection{Molecular signaling within neurons}
#
# \section{Sensation and sensory processing}
# 1. Introduction
# Sensory receptors are usually specialized neurons or epithelial cells that detect external or internal stimuli -> sensory transduction -> transmission -> perception
# Mechanoreceptors, mekaaniset reseptorit, mekaniska receptorer: iho, lihas, sisäkorva, verisuonet, sydän
# Chemoreceptors, kemoreseptorit, kemoreceptorer:
# Electromagnetic receptors, sähkömagneettiset reseptorit, elektromagnetiska receptorer:
# Thermoreceptors, termoreseptori, termoreceptor:
# pain -> nocireceptors, excess heat, pressure, chemicals
# 2. Ärsykkeen välittyminen
# Amplifikaatio: ärsykkeen vahvistaminen
# Transduktio: ärsykkeen energian muuttaminen ionivirroiksi
# Receptor potential, Reseptoripotentiaali, Receptorpotential:
# Transformaatio ja transmissio: reseptoripotenitaalin muuntaminen aktiopotentiaaliksi
# 3. Adaptaatio: jatkuvaan ärsykkeeseen tottuminen, elimistö suodattaa turhaa informaatiota
#
# Sensory cells, Aistinsolut, Sinnesceller:
# Free nerve endings, Vapaat hermopäätteet
# Encapsulated nerve endings, Sidekudoskapselin ympäröimät hermopäätteet,
# Differentiated epithelial cell, Erilliset aistinsolut
#
# \subsection{The somatic sensory system}
#
# \subsection{Pain}
#
# \subsection{Vision: the eye}
# Cornea, Sarveiskalvo, Hornhinna
# Pupil, Pupilli, Pupill
# Iris, Iiris, Irishinna
# Lens, Linssi eli mykiö, Lins
# Anterior chamber, Etukammio, Kammarvatten
# Posterior hamber, Takakammio
# Ciliary body and muscles, Sädekehä ja -lihakset, Ciliarmuskler
# Vitreous body, Lasiainen, Glaskropp
# Macula lutea, Keltatäplä, Gula fläcken
# Optic disk, Sokea täplä, Blinda fläcken
# Retina, Verkkokalvo, Näthinnan
# Choroid, Suonikalvo, Åderhinna
# Sclera, Kovakalvo, Senhinna
#
# Ocellus, pistesilmä, punktöga: linssi
# compound eye, ommatida, verkkosilmä, fasettögön:
#
# Bipolar cells, Bipolaariset solut, Bipolära celler
# Horizontal cells, Horisontaalisolut, Horisontalceller
# Amacrine cells, Amakriinisolut, Amakrina celler
# Müller cells, Müllerin solut, Müllers celler
#
#
# Retina, Verkkokalvo, Näthinnan
#
# Photoreceptors, Photoreseptorit, Photoreceptorer
# Rods, sauvat, stavar: one type, greyscale vision,stimulated in dim light as well
# Cones, tapit, tappar: three different groups of cones,
#
# Visual pigments
# Rhodopsin=retinal + opsin
#
# Dark: rhodopsin inactive, Na channels are open -> depolarize -> glutamate
# Light: rhodopsin active, retinal changes from cis to trans, rhodopsin is cleaved into retinal and opsin- Na channels are closed -  -> hyperpolarize
#
# \subsection{Central visual pathways}
#
# \subsection{The auditory system}
# Outer ear, Ulkokorva, Ytteröra
# Penna, Korvalehti, Öronmussla
# Auditory canal, korvakäytävä, hörselgången
# Tympanic membrane, tärykalvo, trumhinna
#
# Middle ear, Välikorva, Mellanöra
# malleus, vasara, hammare
# Incus, alasin, städet
# Stepes, jalustin, stigbygeln
#
# Oval window, Ovaali ikkuna, Ovala fönstret
# Cocea, Simpukka, Snäcka
# Roudn window, Pyöreä ikkuna, Runda fönstret
# Eustachian tube, Korvatorvi, Örontrumpet
#
# Scala vestibuli, Vestibular canal, Eteiskäytävä
# Organ of Corti, Cortin elin, Cortis organ
# Reissner’s membrane, Reissnerin kalvo, Reissner’s membran
# Hair cells, karvasolut, hårceller
# Tectorial membrane, Katekalvo, Täckmembran
# Lamina basilaris, Basilar membrane, Tyvilevy, basalmembran
# Scala media, Simpukkatiehyt,
#
#
# \subsection{The vestibular system}
# Semicircular calan, kaarikäytävät, Balansgångar eller båggångar: angular movements, perilymph, cupula, hair cells
# Cupula, Hyytelökeko, Gelékon
# utricle, soikea rakkula, ovala hinnsäcken
# saccule, pyöreä rakkula, runda hinnsäcken
# gravity, linear movement, otoliths, cupula
# Kylkiviiva, Sidolinjen
# Statocyst, Statokysti, Statokyst: statoliths in chamber, ciliated receptor cells sense their location
#
# \subsection{The chemical senses}
# 4. Gustation and olfaction, Maku ja haju, Smak och lukt
# Chemoreceeptros, taste buds, : sweet,, sour, salty, bitter, umami
# Maksusilmut, makea, hapan, suolainen, karvas, umami
# Smaklök söt, sur, salt, besk, umami
# Nasal cavity, olfactory bulb
#
# Taste buds, Makusimlut, Smaklökar
#
# Ihmisen hajuaisti: signaali menee suoraan limbiseen järjestelmään
#
#
# \section{Movement and its central control}
#
# \subsection{Lower motor neuron circuits and motor control}
#
# \subsection{Upper motor neuron control of the brainstem and spinal cord}
#
# \subsection{Modulation of movement by the basal ganglia}
#
# \subsection{Modulation of movement by the cerebellum}
#
# \subsection{Eye movement and sensory motor integration}
#
# \subsection{The visceral motor system}
#
# \section{The changing brain}
#
# \subsection{Early brain development}
#
# \subsection{Construction of neural circuits}
#
# \subsection{Modification of brain circuits as a result of experience}
#
# \subsection{Plasticity of mature synapses and circuits}
#
# \section{Complex brain functions}
#
# \section{Electrophysiological techniques}
# Basic measurements and devices, simple circuits, equivalent circuits, sources of error
# Axoclamp 2B. Master-8, model cell, oscilloscope
# Voltage recording, current injection, 2-microelectrode current clamp and voltagre clamp, 1-microelectrode techniques (bridge mode current clamp, discontinuous mode current clamp, whole cell patch clamp: current clamp, whole cell parch clamp: voltage clamp
# Reversal potential measurements
# Noise in electrophysiological experiments, data acquisition, other topics
#
# \subsection{Part 1 Theory}
# Electricity, electrical properties of cell/tissue preparations
# Microelectrodes, voltage recording amplifiers, equivalent circuit approach, basic recording modes, current clamp and voltage clamp
#
# \subsubsection{Charge}
# Q, q, an inherent property of particles
# Elementary charge e = 1.6021e-19 C
# Integer multiplies of elementary charge
# Faraday constant F, the charge of 1 mole of monovalent ions
#
# \subsubsection{Current}
# Any movement of charge, I, i
# \[
# I = \frac{Q}{t}
# \]
# The direction of current = direction of positive charge
#
# \subsubsection{Electrical potential and voltage}
# Potential difference is what makes charge move, voltage provides driving force for current
# Ionic current carried by a single ion species is not zero at zero membrane potential but at the equilibrium potential (Nernst potential), driving force of the ionic current is offset from zero
# Potential difference = voltage
# Membrane potential = potential difference!
#
# Intracellular recordings: the extracellular potential is assumed as zero.
# Extracellular field potential recordings: local potential measured with respect to more distant site
# DC: direct current
# AC: alternatig current
#
# Peak voltage, peak to peak voltage, root mean square voltage (equals the DC voltage that would have the same power in a resistor)
#
# \subsubsection{Resistance, conductance and impedance}
# Ohm's law
# \[
# I = \frac{V}{R}
# \]
# Resistance has no frequency dependence!
# Impedance is frequency dependent
#
# Conductance is the reciprocal of the resistance
# \[
# G = \frac{1}{R}
# \]
# \subsubsection{Capacitance}
# Two conductors separated from each other by an insulator
# \[
# C = \frac{Q}{V}
# \]
# The membrane capacitance becomes charged and this is seen as a membrane potential
#
# Capacitive current: when current brings charge into a capacitor (closed circuit), an equal amount of charge will leave from the opposite side
#
# \[
# I_{C} = C \frac{\Delta V}{\Delta t}
# \]An inward current via ion channels into a  cell causes depolarization of the cell membrane by charging the cell membrane capacitance
#
# In animal cells, intracellular Na+ concentration is rather low, and the amount of Na+ needed to generate a depolarization is negligible compared to the Na+ content of the cell.
#
# \subsubsection{Current and voltage sources}
# Ideal voltage source = a two node component that maintains a given voltage no matter how much current is drawn from the voltage source
#
# A real voltage source is modelled by a series connection of an ideal voltage and source and a resistor called internal resistance or output resistance.
#
# \subsubsection{Series and parallel connections of resistors and capacitors}
# Resistance in series:
# \[
# R_{eq} = R_1 + R_2 + \dots + R_n
# \]Resistance in parallel:
# \[
# \frac{1}{R_{eq}} = \frac{1}{R_1} + \frac{1}{R_2} + \dots \frac{1}{R_n}
# \]
# Capacitance in series:
# \[
# \frac{1}{C_{eq}} = \frac{1}{C_1} + \frac{1}{C_2} + \dots \frac{1}{C_n}
# \]
# Resistance in parallel:
# \[
# C_{eq} = C_1 + C_2 + \dots + C_n
# \]\subsubsection{Kirchoff's circuit laws}
# Kirchoff's first law, the current law: the sum of currents entering a junction equals zero at all times
#
# Kirchoff's second law, the voltage law: the sum of voltages across circuit elements in a closed loop equals zero at all times
#
# \subsubsection{Voltage divider circuit}
# \[
# V_{R_2} = \frac{R_2}{R_1 + R_2 + R_3} V
# \]\subsubsection{RC circuits}
# Initially the switch is open and the capacitor is uncharged. When the switch is closed, the cpacitve current starts to charge up the capacitance, and the voltage across the capacitance starts to increase gradually. Voltage across the resistance decreases while voltage across the capacitance increases. Finally, the voltage of the capacitance reaches the voltage of the battery, there is no voltage across the resistance, and there is no longer any current flow in the circuit.
# \[
# V_{C} = V_0 \Bigg( 1 - e^{-\frac{t}{RC}} \Bigg)
# \]Parallel RC circuit: When current injection starts, the capacitor is without charge and voltage, and there is no current flow through the resistor. After onset all current flows to the capacitor. Current via the capacitor generates a gradually increasing voltage, giving rise to a gradually increasing current through the resistor.
# \[
# I_{tot} = I_C + I_R
# \]
# \subsubsection{Filters}
# Frequency and frequency content:
# The square wave consists of subwaves, the amplitude or power spectrum of the signal. The plot shows what sine wave frequencies togehter form the signal and what are their relative intensities.
#
# Low pass (LP), high pass (HP), band pass (BP) and band reject (BR). Low pass filter: frequencies below a certain cut-off frequency are passed through.
#
# Filters induce phase shift and other unwanted changes in the signal
#
# Increase in the frequency of the input signal, there is less and less time for the voltage across the capacitor to change. The peak amplitude becomes smaller and smaller, and we observe a low pass filtering effect.
#
# Lower frequencies appear across the capacitor whereas higher frequencies will be seen across the resistor
#
# \subsubsection{Electrodes and amplifiers}
# Electrodes including the Ag/AgCl electrode, stimulation electrodes, microelectrodes, non-idealities of real voltage recording amplifiers
#
# Diffusion potential: the kind of potential gradient within a continuous fluid phase that is a consequence of different diffusion speeds
#
# Liquid junction potential: the potential difference existing between two electrolyte solutions that are in direct contact. It is generated by the ions diffusing between the solutions.
# $V_{LJP}$ , present in extracellular fluid, in the cell the gets perfused by the pipette, no LJP
#
# \subsubsection{The silver-silverchloride electrode}
# Highly reversible electrode
#
# \subsubsection{Microelectrodes for voltage recording}
# For recording voltage signals, we should have electrodes that transmit the steady state value and shifts of electrical potential from an aqueous solution. Metal electrodes are not stable!
#
# The electrical potential of the silver wire will not be the same as the potential of the solution, but the difference (offset potential) will remain constant, because the concentration of Cl is constant.
#
# \subsubsection{Voltage signals}
# VAg/AgCl is assumed to remain constant, eliminated by zeroing input offset
#
# Passive electrical properties of microelectrodes:
# Tip resistance and capacitance across the glass wall
#
# \subsubsection{Amplifiers: ideal vs. real voltage-recording amplifiers}
# Input resistance. Input resistance
