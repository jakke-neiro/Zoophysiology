# %% [markdown]
# \section {Cardiovascular physiology}
# 3. Blood circulation
# 1. Introduction
# Blood circulation: The circulatory system, also called the cardiovascular system or the vascular system, is an organ system that permits blood to circulate and transport nutrients (such as amino acids and electrolytes), oxygen, carbon dioxide, hormones, and blood cells to and from the cells in the body to provide nourishment and help in fighting diseases, stabilize temperature and pH, and maintain homeostasis.
# Verenkierto: kehon kuljetusjärjestelmä
# Blodcirkulationen: Kardiovaskulära systemet, hjärt- och kärlsystemet eller blodcirkulationssystemet, är det organsystem som transporterar ämnen mellan cellerna och som även hjälper till att reglera pH och kroppstemperatur. Organsystemet består av hjärta och blodkärl, och sjukdomarna som drabbar systemet brukar benämnas hjärt- och kärlsjukdomar.
#
# 2. Circulatory systems, Verenkiertoelimistöt, Cirkulationssystem
# 1. Gastrovascular cavity (sponges, cnidaria, flatworms)
# The gastrovascular cavity: is the primary organ of digestion and circulation in two major animal phyla: the Cnidaria (including jellyfish and corals) and Platyhelminthes (flatworms). The cavity may be extensively branched into a system of canals.
#
#
# 2. Open circulatory system, hemolymph  (insects)
# The open circulatory system: is a system in which a fluid in a cavity called the hemocoel bathes the organs directly with oxygen and nutrients and there is no distinction between blood and interstitial fluid; this combined fluid is called hemolymph or haemolymph.[13] Muscular movements by the animal during locomotion can facilitate hemolymph movement, but diverting flow from one area to another is limited. When the heart relaxes, blood is drawn back toward the heart through open-ended pores (ostia).
# Avoin verenkierto: osan aikaa verisuonten ulkopuolella
# Öppet blodomlopp:
#
# 3. Closed circulatory system, blood
# Closed circulatory system: A circulatory system in which blood is confined to vessels and is kept separate from the interstitial fluid.
# Suljettu verenkierto: verenkiertojärjestelmä jossa veri pysyy verisuonissa ja pidetään ruumiinnesteestä erillään.
# Slutet blodomlopp:
# <- more efficient oxygen transport, bigger blood pressure, better excreation
# Single closed circulatory system: the system has only one circuit, with the blood being pumped through the capillaries of the gills and on to the capillaries of the body tissues.
#
# Double closed circulatory system: This means that we have two loops in our body in which blood circulates. One is oxygenated, meaning oxygen rich, and the other is deoxygenated, which means it has little to no oxygen, but a lot of carbon dioxide.
# Kaksinkertainen verenkierto, mahdollistaa korkean verenpaineen systeemisessä verenkierrossa mutta vähentää nesteen filtraatiota keuhkon hiussuonista ulos
# 3. Cardiovascular system, Verenkiertoelimistö, Blodcirkulationssystemet
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Left atrium, Vasen eteinen, Vänster förmak
# The atrium (plural: atria) is one of the two blood collection chambers of the heart.
# Mitral valve, Vasen eteiskammioläppä, mitraaliläppä, hiippaläppä, mitralisklaff
# Left ventricle, Vasen kammio, Vänster kammare
# In the heart, a ventricle is one of two large chambers that collect and expel blood received from an atrium towards the peripheral beds within the body and lungs.
# Aortic semilunar valve, Kammiovaltimoläppä, aorttaläppä, aortaklaff
# Blood vessels, Verisuonet, Blodkärl
# Aorta, Aortta, Aorta
# The aorta (/eɪˈɔrtə/) is the main artery in the human body, originating from the left ventricle of the heart and extending down to the abdomen, where it splits into two smaller arteries (the common iliac arteries).
# Artery, Valtimot, Artärer
# Arteries (from Greek ἀρτηρία (artēria), meaning "windpipe, artery")[1] are blood vessels that carry blood away from the heart. While most arteries carry oxygenated blood, there are two exceptions to this, the pulmonary and the umbilical arteries.
# Systemic circuit, Systeeminen verenkierto, Systemiska blodcirkulationen
# Coronary arteries/veins, Sepelverisuonet, Kransblodkärl
# Coronary circulation is the circulation of blood in the blood vessels of the heart muscle (myocardium). The vessels that deliver oxygen-rich blood to the myocardium are known as coronary arteries. The vessels that remove the deoxygenated blood from the heart muscle are known as cardiac veins.
# Arterioles, pikkuvaltimo, arterioler
# Capillaries, Hiussuonet, Kapillärer
# Vein, Laskimo, Ven
# In the circulatory system, veins (from the Latin vena) are blood vessels that carry blood toward the heart. Most veins carry deoxygenated blood from the tissues back to the heart; exceptions are the pulmonary and umbilical veins, both of which carry oxygenated blood to the heart.
# Superior vena cava, Ylempi onttolaskimo, Övre hålven
# Inferior vena cava, Alempi onttolaskimo, Nedre hålven
# Right atrium, Oikea eteinen, Höger förmak
# Tricuspid valve, Oikea eteiskammioläppä, kolmiliuskaläppä, trikuspidalklaff
# Right ventricle, Oikea kammio, Höger kammare
# Pulmonary semilunar valve, puolikuuläppä, kammiovaltimoläppä, keuhkovaltimoläppä, pulmonalisklaff
# Pulmonary circuit, Keuhkoverenkierto, Lungcirkulationen
# Pulmonary artery, Keuhkovaltimo, Lungartär
# Lungs, Keuhkot, Lungor
# Pulmonary vein, Keuhkolaskimo, Lungven
#
#
# 3. Blood pressure and flow
#
# 1. Cardiac cycle, Sydämen sykli, Hjärtcykeln
#  1. A+v diastole 2. Asystole 3. V systole
#
#
# 2. Heart rhythm,
# Electrical conduction system of the heart, Impulssinjohtojärjestelmä, Hjärtats retledningssystem
# 1. SA node, sinussolmuke, sinusknutan Höger förmak uppe
# Pacemakerpotential, spontan depolarisering, Ca2+/Na+ in och K+ kan inte gå ut, pacemakerpotentialen kan regleras, :
# 2. AV node, eteiskammiosolmuke, atrioventrikulärknutan Höger förmak nere
# Uppehållning, blodet tömmas ner i kamrarna,
# 3. His bundle, Hisin kimppu, His-bunten
# 4. Purkinje fibers, Purkinjen säikeet, Purkinjefibrer
# Höger och vänster kammare kontraherar efter hela sin utbredning
# 4. Blood pressure and flow,
# Heart attack, stroke
# Kidney erythropoietin (EPO), atherosclerosis
# Heart rate, Sydämen syke, Hjärtfrekvens: parasympaattinen jarruttelee, Sympaattinen hermosto kiihdyttää, adrenaliini
# Stroke volume, Iskutilavuus, Slagvolymen
# Cardiac output, Minuuttitilavuus, Hjärtminutvolymen
# Blood pressure, verenpaine, blodtryck: minuuttitilavuus * ääreisvastus
# Ääreisvastus=verisuonen sisäläpimitta, veren viskositeetti
# Venous valves, Laskimoläpät, Venklaffar and skeletal muscles, luustolihakset, skelettmuskler
# Hiussuonet:  sphincters, sulkijalihakset, slutarmuskler
# Valtimo: verenpainee suodattaa veriplasmaa ulos
# Laskimo: proteiinipitoisuus mm albumiini, osmoottinen paine imee vettä takaisin hiussuoniin, osa nesteestä palaa imusuonten välityksellä takaisin
# Blood vessels, Verisuonet, Blodkärl
# Suuret
# Keskikokoset
# Arterioles, Pikkuvaltimot, Arterioler
# Venules, Pikkulaskimot, Venuler
# Lumen
# 1. Tunica interna,
# Endothelium, Endoteeli, Endotel: yksikerroksinen levyepiteeli, aineiden kuljetus verestä kudoksiin, kasvutekijöiden ja entsyymien eritys, lymfosyyttien kulkeutuminen verestä kudoksiin
# Basement membrane,
# Internal elastic lamina
# 2. Tunica media, Keskikalvo,
# Elastiinikalvoja,
# Smooth muscle, Sileä lihaskudos, Glatt muskelvävnad: kehänsuuntaisia, circular, ringmuskler
# External elastic lamina
# 3. Tunica externa sive adventitia:
# Hiussuonten seinämän rakenne
# Continuous, Yhtenäiset hiussuonet, Kontinuerlig
# Fenestrated, Ikkunalliset hiussuonet, Fenestrerad
# Discontinuous or sinusoids, Epäyhtenäinen eli Sinusoidit, Diskontinuerlig l. sinusoider
#
# \section{Blood flow and the control of blood pressure}
#
# \section{Blood}
# 5. Blood components
#
#
# 1. Blood cells, Verisolut, Blodkroppar 45%
# Verisolut erilaistuvat luuytimessä
#
# 1. Erytrocytes, Erytrosyytit eli punasolut, Erytrocyter alltså röda blodkroppar
# Red blood cells (RBCs), also called erythrocytes, are the most common type of blood cell and the vertebrate organism's principal means of delivering oxygen (O2) to the body tissues—via blood flow through the circulatory system.[1] RBCs take up oxygen in the lungs or gills and release it into tissues while squeezing through the body's capillaries.
# Punasolut: selkärankaisten veren hemoglobiinin sisältävä solu, erytrosyytti, joka kuljettaa hengityskaasuja
# Röda blodkroppar: Röda blodkroppar, erytrocyter, är en del av blodet och utgör tillsammans med vita blodkroppar, leukocyter, och blodplättar, trombocyter, nära 50 % av blodet. Deras uppgift är att frakta syre till cellerna, och koldioxid från dem till lungorna.
#
# 2. Leucocytes, Leukosyytit eli valkosolut, Leukocyter alltså vita blodkroppar: immunity
# White blood cells (WBCs), also called leukocytes or leucocytes, are the cells of the immune system that are involved in protecting the body against both infectious disease and foreign invaders
# Valkosolut: selkärankaisten valkoinen verisolu. Valkosolut toimivat elimistön fysiologisessa puolustuksessa.
# Vita blodkroppar: Vita blodkroppar eller leukocyter är celler i blodet som ingår i kroppens immunförsvar för att skydda kroppen mot infektionssjukdomar.
#
# Granulocytes, Granulosyytit, Granulocyter
# Granulocytes: Granulocytes are a category of white blood cells characterized by the presence of granules in their cytoplasm.[1] They are also called polymorphonuclear leukocytes (PMN, PML, or PMNL) because of the varying shapes of the nucleus, which is usually lobed into three segments.
# Granulosyytit: jyvässolut; selkärankaisten veren valkosoluihin kuuluva solutyyppi. Niiden solulimassa on jyväsiä (rakkuloita, granuloita), joiden värjäytyvyyden mukaan granulosyytit on nimetty.
# Granulocyter: Granulocyter är ett slags vita blodkroppar som kännetecknas av att de innehåller granula[1] i cytoplasman. Granula (sing. granulum) är små korn[1] som finns i cytoplasman till vissa immunceller/granulocyter[2] samt förstadier till dessa och andra blodceller[3].
#
#
#
# Neutrophil granulocytes (also known as neutrophils or occasionally neutrocytes) are the most abundant type of granulocytes and the most abundant (40% to 75%) type of white blood cells in most mammals. They form an essential part of the innate immune system. Functionality varies in different animals
# Neutrofiili: bakteereita tappavia ja fagosytoivia soluja, jotka työntyvät hiussuonista myös muihin kudoksiin; niitä on noin puolet veren kaikista valkosoluista.
# Neutrofiler: Neutrofiler hanterar försvaret mot bakterieinfektioner och andra mycket små inflammationsprocesser, och är vanligtvis de första försvararna mot bakterieangrepp. Det var som uppstår vid sårläkning består till stor del av döda neutrofiler.
#
# Eosinophil granulocytes: usually called eosinophils or eosinophiles (or, less commonly, acidophils), are a variety of white blood cell and one of the immune system components responsible for combating multicellular parasites and certain infections in vertebrates. Along with mast cells, they also control mechanisms associated with allergy and asthma.
# Eosinofiilit: tappavat joitakin mikrobeja ja aktivoituvat allergiareaktioissa;
# Eosinofil: Eosinofiler produceras vid infektioner orsakade av endoparasiter och en ökning av antalet eosinofiler kan indikera en sådan infektion.
#
# Basophils appear in many specific kinds of inflammatory reactions, particularly those that cause allergic symptoms. Basophils contain anticoagulant heparin, which prevents blood from clotting too quickly. They also contain the vasodilator histamine, which promotes blood flow to tissues
# Basofiili: osallistuu tulehdusreaktioihin, erittää histamiinia, histamiinia ja hepariinia vapauttavia soluja, joita on prosentti valkosolujen kokonaismäärästä:
# Basofil: Basofiler ansvarar huvudsakligen för att hantera allergier och rekryteras till vävnad där antigen påträffas. Genom frisättning av histamin stimuleras inflammationen i den angripna vävnaden.
#
# Mast cell:
# Syöttösolu: selkärankaisten sidekudoksen solutyyppi, jota on erityisen runsaasti hiussuonten ympärillä; soluja, joiden sisällä olevat pienet rakkulat sisältävät hepariinia, histamiinia ja proteaaseja, joita solu erittää eksosytoottisesti tulehdus- ja allergiareaktioissa kudosnesteeseen ja vereen.
# Mastcell: Mastceller bekämpar parasiter, speciellt maskar som infekterat kroppen [[]] Mastceller finns i bindväv och är långsmal med rund kärna och kontrasterande basofil granulae i cytoplasman. Cellmembranet är veckat och det har mikrovilli.
#
# Agranulocytes (lymphocytes, monocytes)
# Monocytes: They are part of the innate immune system of vertebrates including all mammals (humans included), birds, reptiles, and fish. They are amoeboid in shape, having agranulated cytoplasm.
# Monosyytit: selkärankaisten veren suurin valkosolutyyppi, jossa on yksi suuri pitkulainen tai munuaisenmuotoinen tuma. Solu on ameebamaisesti liikkuva ja toimii elimistön puolustuksessa fagosyyttinä syöden elimistölle haitallisia aineita ja mikrobeja.
# Monocyter: Monocyterna har liksom neutrofilerna "storätar-egenskaper" (fagocytos), men är mer långlivade, då de har ytterligare en roll: de uppvisar bitar av patogen för de patrullerande T-cellerna så att patogenen kan kännas igen och bli oskadliggjorda igen, eller se till att en antikroppsåtgärd aktiveras.
#
# Makrofagi: Siirtymisen jälkeen monosyytit erilastuvat edelleen, jolloin niistä muodostuu kudosmakrofageja. Nämä pystyvät puolustamaan kudoksia fagosytoimalla ja tuhoamalla vierasta materiaalia, kuten mikrobeja ja solufragmentteja. Ne ottavat itseensä myös antigeenejä, käsittelevät niitä esim. hajottamalla niitä ja tarjoavat niitä T-imusoluille.
# Makrofag: Monocyter kallas makrofager efter att de vandrat över från blodomloppet och in i vävnaden.
#
# Lymfosyytit: immuunivaste
# Lymfocyter: Lymfocyter är en sorts vita blodkroppar som är huvuddelen i det adaptiva immunförsvaret.
#
# B-lymfocyter: bildar antikroppar som binder till patogenet för att förstöra det. B-celler angriper främmande element som befinner sig utanför cellerna. B-cellerna bygger upp det humorala immunförsvaret.
# T-celler eller T-lymfocyter är en typ av vita blodkroppar som utgör en del av den adaptiva delen av kroppens immunförsvar. De utbildas för att känna igen specifika patogener.
# Dendritiska celler är professionella antigenpresenterande celler. Dessa fagocyterar främmande ämnen, inkräktande mikroorganismer (etc.) och presenterar dessa för T-hjälparceller.
#
# 3. Trombocytes, Trombosyytit eli verihiutaleet, Trombocyter alltså blodplattor (platelets), blood clottingThrombin+clotting factors+K-vitamine -> Fibrinogen -> Fibrin -> blood clotting
#
# 2. Blood plasm 55 %
# 1. Water solvent
# 2. Ions osmotic balance, pH buffering
# 3. Proteins: albumin, fibrinogen, immunoglobulin
# 4. Nutrients
# 5. Waste-products, Kuona-aineet, Slaggämnen
# 6. Hormones, Hormonit, Hormoner
# Hermosto ja hormonit säätelevät sydämen toimintaa
# Paine-erot saavat veren kiertämään
